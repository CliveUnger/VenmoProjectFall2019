# %%
import pandas as pd

df = pd.read_csv('/home/06271/cju256/cc_per_month_nonull.csv').drop(df.columns[0], axis = 1)
df.head()
# Out:
#      month  nodes  edges        cc  cc_weighted  cc_nozeros  \
# 0  2012-03     17     13  0.000000     0.000000    0.000000
# 1  2012-04   3512   2520  0.025979     0.000347    0.398424
# 2  2012-05   4643   3404  0.033128     0.001669    0.419110
# 3  2012-06   4990   3710  0.029863     0.002151    0.419767
# 4  2012-07   5655   4171  0.034595     0.000832    0.413599
#
#    cc_weighted_nozeros
# 0             0.000000
# 1             0.005320
# 2             0.021115
# 3             0.030241
# 4             0.009951

# %%
df = df[df.month != '2018-07']
df = df[df.month != '2018-08']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))
plt.xticks(rotation=75)
plt.plot(df['month'], df['cc']);

# %%
plt.figure(figsize=(16,4))
plt.xticks(rotation=75)
plt.plot(df['month'], df['cc_weighted']);

# %%
plt.figure(figsize=(16,4))
plt.xticks(rotation=75)
plt.plot(df['month'], df['cc_nozeros']);

# %%
plt.figure(figsize=(16,4))
plt.xticks(rotation=75)
plt.plot(df['month'], df['cc_weighted_nozeros']);
